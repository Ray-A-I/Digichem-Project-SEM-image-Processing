# %% [markdown]
# AE feature extractor, main operator is main().
# Change image folder to your labeled SEM image folder.
# Model path to your trained VAE model.
# Output to your desire CSV file name.
# Specify latent dimensions.
# Combines with template.csv to include full Magpie Features.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from PIL import Image
import os
import csv
import pandas as pd

# %%
transform = transforms.Compose([
    transforms.Resize((256, 144)),  # Adjust if needed
    transforms.Grayscale(),         # Optional depending on model
    transforms.ToTensor(),          # Converts to CxHxW and scales to [0,1]
    transforms.Normalize([0.5], [0.5])  # Normalize if model expects it
])

# %%
import torch
import torch.nn as nn

class VAE(nn.Module):
    def __init__(self, latent_dim=2048):
        super(VAE, self).__init__()
        self.latent_dim = latent_dim

        # Encoder with Dropout
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),
            #nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            #nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
        )


        self.flattened_size = 128 * 18 * 32

        self.fc_mu = nn.Linear(self.flattened_size, latent_dim)
        self.fc_logvar = nn.Linear(self.flattened_size, latent_dim)

        self.decoder_input = nn.Linear(latent_dim, self.flattened_size)

        # Decoder with light Dropout (optional)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            #nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),
            #nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Dropout(0.1),

            nn.ConvTranspose2d(32, 1, kernel_size=4, stride=2, padding=1),
            nn.Sigmoid(),
        )

    def encode(self, x):
        x = self.encoder(x)
        x = x.view(-1, self.flattened_size)
        return self.fc_mu(x), self.fc_logvar(x)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        x = self.decoder_input(z)
        x = x.view(-1, 128, 18, 32)
        return self.decoder(x)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
def extract_features(model_path, image_folder, output_csv, latent_dim=2048,
                     template_csv=None):
    """
    Extract latent features from images using a VAE model and save to CSV.

    Output columns order:
    - Column 1: image filename (no path)
    - Columns 2-4: empty (or can be customized)
    - Column 5: replaced by template's 5th column (index 4)
    - Columns 6...: latent descriptors
    - Optionally appended columns from "MagpieData minimum Number" onward from template

    Parameters:
    - model_path: path to saved VAE model state_dict
    - image_folder: folder containing images
    - output_csv: CSV file to save features
    - latent_dim: latent vector dimension
    - template_csv: optional path to template CSV for replacing and appending columns
    - append_template_cols: if True, append columns after "MagpieData minimum Number" from template CSV
    """
    append_template_cols=True
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = VAE(latent_dim=latent_dim).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    transform = transforms.Compose([
        transforms.Resize((144, 256)),
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])

    rows = []

    # Collect image files sorted to ensure consistent ordering
    image_files = []
    for root, _, files in os.walk(image_folder):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.tif')):
                image_files.append(os.path.join(root, file))
    image_files.sort()

    for img_path in image_files:
        try:
            image = Image.open(img_path).convert('L')
            tensor = transform(image).unsqueeze(0).to(device)
            with torch.no_grad():
                mu, _ = model.encode(tensor)
            mu_np = mu.squeeze().cpu().numpy()
            file_name = os.path.basename(img_path)
            # Compose row:
            # col1 = filename
            # col2, col3, col4 = empty strings (placeholders)
            # col5 = placeholder for template value (to be replaced later)
            # col6... = latent features
            row = [file_name, '', '', '', ''] + mu_np.tolist()
            rows.append(row)
            print(f"Extracted: {img_path}")
        except Exception as e:
            print(f"Failed: {img_path}, Error: {e}")

    if template_csv is None:
        # Save without template merging
        with open(output_csv, 'w', newline='') as f:
            writer = csv.writer(f)
            header = ['filename', 'col2', 'col3', 'col4', 'template_col5'] + [f'descriptor_{i}' for i in range(latent_dim)]
            writer.writerow(header)
            writer.writerows(rows)
        print(f"Saved features to {output_csv}")
        return

    # Load template CSV
    df_template = pd.read_csv(template_csv)

    if len(rows) != len(df_template):
        raise ValueError(f"Row count mismatch: extracted {len(rows)} rows vs template {len(df_template)} rows.")

    # Replace 5th column with template's column 5 values
    col5_values = df_template.iloc[:, 4].tolist()

    # Get start index of "MagpieData minimum Number"
    if append_template_cols:
        if "MagpieData minimum Number" not in df_template.columns:
            raise ValueError("Template CSV missing 'MagpieData minimum Number' column.")
        magpie_start_idx = df_template.columns.get_loc("MagpieData minimum Number")
        magpie_headers = df_template.columns[magpie_start_idx:].tolist()
        magpie_values = df_template.iloc[:, magpie_start_idx:].values
    else:
        magpie_headers = []
        magpie_values = None

    merged_rows = []
    for i, row in enumerate(rows):
        new_row = list(row)
        new_row[4] = col5_values[i]  # Replace column 5
        if append_template_cols:
            new_row.extend(magpie_values[i])  # Append Magpie columns
        merged_rows.append(new_row)

    # Build header:
    # First 5 columns:
    # 1: 'filename'
    # 2-4: placeholders or empty
    # 5: template's 5th column header
    base_header = ['filename', 'col2', 'col3', 'col4', df_template.columns[4]]

    # Then latent descriptors
    latent_headers = [f'descriptor_{i}' for i in range(latent_dim)]

    # Append Magpie headers if applicable
    if append_template_cols:
        header = base_header + latent_headers + magpie_headers
    else:
        header = base_header + latent_headers

    with open(output_csv, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(merged_rows)

    print(f"Saved merged CSV to {output_csv} with template columns appended={append_template_cols}")

# %%
if __name__ == "__main__":
    image_folder = r"Preprocessed Images\Labeled SEM\ourimg_normgrey"
    model_path = r"Trained Models\Example VAE Finetuned Model.pth"
    output_csv = r"Extracted Features\Example VAE Features.csv"
    template = r'Miscelleous\template.csv'
    latent_dim = 2048

    extract_features(model_path, image_folder, output_csv, latent_dim, template)
# Out:
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\0perc_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\0perc_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\0perc_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\0perc_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\0perc_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10perc_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10perc_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10perc_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\10perc_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\15perc_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\20_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_07.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_08.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_09.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_SE2_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_SE2_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\2PACz_SE2_10.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5perc_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5perc_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5perc_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5perc_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\5perc_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_07.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Blend_08.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_0_SE2_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_08.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_09.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_10.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_11.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_12.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_13.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_14.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_SE2_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_10_SE2_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_15.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_16.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_17.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_15_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_SE2_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_20_SE2_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_07.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_08.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_09.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_25_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_07.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_SE2_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_SE2_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_SE2_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Cs_5_SE2_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Dev9_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\DevX_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1000.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1001.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1002.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1003.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1004.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1500.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1501.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1502.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_1503.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2000.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2001.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2002.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2003.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2004.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2005.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2006.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2007.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_2008.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_500.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_501.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_502.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_503.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_504.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_505.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_Ref00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_Ref01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_Ref02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Matilde_Ref03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_06.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Me-4PACz_07.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\REF_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\REF_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\REF_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH20_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH20_04.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH20_05.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH80_real_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH80_real_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH80_real_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T100_RH80_real_03.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T20_RH20_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T20_RH20_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T20_RH20_02.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T20_RH80_00.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\T20_RH80_01.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z10A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z10B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z10C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z10D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z10E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z11G.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z12A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z12B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z12C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z12D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z12E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z13G.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14G.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14H.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z14I.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z15A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z15B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z15C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z15D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z15E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16G.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16H.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16I.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z16J.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z17A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z17B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z17C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z17D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z18A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z18B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z18C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z19A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z19B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z19C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z19D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z1A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z1B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z1C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z1D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z20A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z20B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z21A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z21B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z21C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z22A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z22B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z22C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z22D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z22E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z23A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z24F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z25A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z25B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z25C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z25D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z26A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z26B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z26C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z26D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z27A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z28A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z28B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z28C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z28D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z29A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z29B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z29C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z2A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z2B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z2C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z2D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z30A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z30B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z30C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z30D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z31A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z31B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z31C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z31D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z31E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z32A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z32B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z32C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z33F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z34A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z34B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z34C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z34D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z35A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z35B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z35C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36G.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z36H.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z3A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z3B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z3C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z4A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z4B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z6A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z6B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7C.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7D.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7E.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z7F.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z8A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z8B.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z9A.jpg
# Extracted: Preprocessed Images\Labeled SEM\ourimg_normgrey\Z9D.jpg
# Saved merged CSV to Example VAE Features.csv with template columns appended=True
